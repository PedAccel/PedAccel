# %% [markdown]
# MAD Statistics

# %%
import os 
from scipy.io import loadmat
import numpy as np
from scipy import stats
from scipy.stats import mannwhitneyu, kruskal, wilcoxon, kstest, anderson
import math
import itertools 
import numpy as np
from scipy.stats import mannwhitneyu, kruskal, kstest, anderson
from fastdtw import fastdtw
import neurokit2 as nk
import matplotlib.pyplot as plt
import pandas as pd

#Place MAD data into SBS groups
data_dir = r"C:\Users\HP\Documents\JHU_Academics\Research\DT 6\NewPedAccel\VentilatedPatientData"
window_size = 100 # 100 is 1 second worth of time

lead_time = 10
slice_size_min = 15

Tag = "Nurse"
Tag = "Retro"

min = 5
min_stat = 10**-3
sr = 100 # Hz

# %%
# Function to calculate Cross-Correlation
def cross_correlation(signal1, signal2):
    return np.correlate(signal1, signal2, mode='full')

# Function to calculate Dynamic Time Warping (DTW)
def dtw(signal1, signal2):
    distance, path = fastdtw(signal1, signal2)
    return distance

# Function to calculate Cliff's Delta
def cliffs_delta(x, y):
    x, y = np.array(x), np.array(y)
    count = 0
    for i in x:
        for j in y:
            if i > j:
                count += 1
            elif i < j:
                count -= 1
    return count / (len(x) * len(y))

# Function to calculate Cohen's d
def cohens_d(x, y):
    diff = np.mean(x) - np.mean(y)
    pooled_std = np.sqrt((np.std(x) ** 2 + np.std(y) ** 2) / 2)
    return diff / pooled_std

# Function to calculate Hedges' g
def hedges_g(x, y):
    d = cohens_d(x, y)
    n1 = len(x)
    n2 = len(y)
    correction_factor = 1 - (3 / (4 * (n1 + n2 - 2) - 1))
    return d * correction_factor

# Function to compare signals
def compare_data(data_1, label_1, data_2, label_2, min_stat=0.05):
    significant_differences = []

    # Cross-Correlation
    cross_corr = cross_correlation(data_1, data_2)
    stat, p_value = mannwhitneyu(data_1, data_2)
    if p_value < 0.05 and p_value > min_stat:
        significant_differences.append(f"Cross-Correlation: {cross_corr}")
        print(f"Significant difference between {label_1} and {label_2} with Cross-Correlation: {cross_corr}")

    # Ensure input data is not empty
    if len(data_1) > 0 and len(data_2) > 0:
        try:
            # Convert inputs to 1D arrays (if needed)
            import numpy as np
            data_1 = np.array(data_1).flatten()
            data_2 = np.array(data_2).flatten()

            # Compute DTW distance
            dtw_distance = dtw(data_1, data_2)

            # Compute Mann-Whitney U test
            stat, p_value = mannwhitneyu(data_1, data_2)

            # Check for statistical significance
            if 0.05 > p_value > min_stat:
                significant_differences.append(f"DTW: {dtw_distance}")
                print(f"Significant difference between {label_1} and {label_2} with DTW: {dtw_distance}")
        
        except Exception as e:
            print(f"Error in DTW calculation: {e}")
    else:
        print("Error: One or both input data arrays are empty.")

    # Mann-Whitney U test
    stat, p_value = mannwhitneyu(data_1, data_2)
    if p_value < 0.05 and p_value > min_stat:
        significant_differences.append(f"Mann-Whitney U test: {p_value:.4f}")
        print(f"Significant difference between {label_1} and {label_2} with Mann-Whitney U test: {p_value:.4f}")

    # Kruskal-Wallis test
    stat, p_value = kruskal(data_1, data_2)
    if p_value < 0.05 and p_value > min_stat:
        significant_differences.append(f"Kruskal-Wallis test: {p_value:.4f}")
        print(f"Significant difference between {label_1} and {label_2} with Kruskal-Wallis test: {p_value:.4f}")

    # Weighted KS Test (requires scipy's ks_2samp)
    stat, p_value = kstest(data_1, data_2)
    if p_value < 0.05 and p_value > min_stat:
        significant_differences.append(f"Weighted KS test: {p_value:.4f}")
        print(f"Significant difference between {label_1} and {label_2} with Weighted KS test: {p_value:.4f}")

    # Kolmogorov-Smirnov test
    stat, p_value = kstest(data_1, data_2)
    if p_value < 0.05 and p_value > min_stat:
        significant_differences.append(f"Kolmogorov-Smirnov test: {p_value:.4f}")
        print(f"Significant difference between {label_1} and {label_2} with Kolmogorov-Smirnov test: {p_value:.4f}")

    # Anderson-Darling test
    result_1 = anderson(data_1)
    result_2 = anderson(data_2)
    p_value_1 = result_1.significance_level[0]
    p_value_2 = result_2.significance_level[0]
    if p_value_1 < 0.05 or p_value_2 < 0.05 and p_value_1 > min_stat and p_value_2 > min_stat:
        significant_differences.append(f"Anderson-Darling test: {p_value_1:.4f}, {p_value_2:.4f}")
        print(f"Significant difference between {label_1} and {label_2} with Anderson-Darling test: {p_value_1:.4f}, {p_value_2:.4f}")

    # Cliff's Delta
    delta = cliffs_delta(data_1, data_2)
    if abs(delta) > 0.474:  # Small, medium, large thresholds for Cliff's Delta
        significant_differences.append(f"Cliff's Delta: {delta:.4f}")
        print(f"Significant difference between {label_1} and {label_2} with Cliff's Delta: {delta:.4f}")

    # Cohen's d
    d = cohens_d(data_1, data_2)
    if abs(d) > 0.5:  # Cohen's d interpretation for large effect
        significant_differences.append(f"Cohen's d: {d:.4f}")
        print(f"Significant difference between {label_1} and {label_2} with Cohen's d: {d:.4f}")

    # Hedges' g
    g = hedges_g(data_1, data_2)
    if abs(g) > 0.5:  # Hedges' g interpretation for large effect
        significant_differences.append(f"Hedges' g: {g:.4f}")
        print(f"Significant difference between {label_1} and {label_2} with Hedges' g: {g:.4f}")

    return significant_differences

# %% [markdown]
# **tsfel features to calculate. Features can be found from MAD data or vector magnitude data**

# %%
#There is no error handling in place, the .mat file must exist
for patient in os.listdir(data_dir):
    # filter out non-directories
    patient_dir = os.path.join(data_dir, patient)
    if os.path.isdir(patient_dir):
        data_filepath_ecg = os.path.join(patient_dir, f'{patient}_{lead_time}MIN_{slice_size_min - lead_time}MIN_ECG_SBSFinal.mat')
        
        if not os.path.isfile(data_filepath_ecg):
            print('skipping')
            continue
        

        ecg_data = loadmat(data_filepath_ecg)
        ecg_SBS = []
        ecg2 = ecg_data['ecg2']
        hrv_indices_final = pd.DataFrame()
        num_scores = np.shape(ecg2)[1]
        print(f'num scores: {num_scores}')

        #Collect all HRV features into a data frame
        for i in range((num_scores)):
            # Clean signal and Find peaks

            current_signal = ecg2[0][i].squeeze()
            if len(current_signal) == 0 or np.all(np.isnan(current_signal)):
                print('Skipping Empty Data')
                continue
                
            try:
                # Compute peaks and HRV indices
                peaks, info = nk.ecg_peaks(current_signal, sampling_rate=250, correct_artifacts=True)
                hrv_indices = nk.hrv(peaks, sampling_rate=250, show=False)
                hrv_indices.dropna(axis=1)
                hrv_indices_final = pd.concat([hrv_indices_final, hrv_indices], axis=0, ignore_index=True, sort=False)
                ecg_SBS.append(ecg_data['sbs_score'][0][i])

            except Exception as e:
                print(f"Error processing signal: {e}")
                continue

        # add SBS
        hrv_indices_final['SBS'] = ecg_SBS
        # Identify columns with no unique values
        cols_to_drop = [col for col in hrv_indices_final.columns if hrv_indices_final[col].nunique() == 1]
        # Drop the identified columns
        hrv_indices_final.drop(cols_to_drop, axis=1, inplace=True)

        for column in hrv_indices_final:
            SBS_neg3 = []
            SBS_neg2 = []
            SBS_neg1 = []
            SBS_zero = []            
            SBS_one = []
            SBS_two = []
            
            if column == 'SBS':
                continue

            feature_metrics = hrv_indices_final[column]
            print(f'Num rows: {len(feature_metrics)}')
            for i in range(len(feature_metrics)):
                ecg_SBS = hrv_indices_final['SBS'][i]
                feature_metric = feature_metrics[i]
                if ecg_SBS == -2:
                    SBS_neg2.append(feature_metric)
                elif ecg_SBS == -1:
                    SBS_neg1.append(feature_metric)
                elif ecg_SBS == 0:
                    SBS_zero.append(feature_metric)           
                elif ecg_SBS == 1:
                    SBS_one.append(feature_metric)
                elif ecg_SBS == 2:
                    SBS_two.append(feature_metric)
                else: 
                    continue
                
            # List of all SBS lists
            SBS_lists = [np.array(SBS_neg2).flatten(), np.array(SBS_neg1).flatten(), np.array(SBS_zero).flatten(), np.array(SBS_one).flatten(), np.array(SBS_two).flatten()]
            SBS_labels = ['SBS_neg2', 'SBS_neg1', 'SBS_zero', 'SBS_one', 'SBS_two']

            #Create 3 class version
            # SBS_lists = [np.concatenate([np.array(SBS_neg2).flatten(), np.array(SBS_neg1).flatten()]), np.concatenate([np.array(SBS_zero).flatten(),np.array(SBS_one).flatten()]), np.array(SBS_two).flatten()]
            # SBS_labels = ['group 1', 'group 2', 'group 3']

            # Compute all possible pairs of lists
            pairs = list(itertools.combinations(range(len(SBS_lists)), 2))
            assert(len(SBS_neg2) + len(SBS_neg1) + len(SBS_zero) + len(SBS_one) + len(SBS_two) > .5 * num_scores)

            # Display pairs and their corresponding labels
            for i, j in pairs:
                list_1 = SBS_lists[i]
                list_2 = SBS_lists[j]
                label_1 = SBS_labels[i]
                label_2 = SBS_labels[j]
                # if(len(list_1)/(slice_size_min * 60) > min and len(list_2)/(slice_size_min * 60) > min):
                if(len(list_1) > min and len(list_2) > min):
                    significant_differences = compare_data(list_1, label_1, list_2, label_2)
# Out:
# skipping
# skipping
# num scores: 11
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: divide by zero encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: divide by zero encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: divide by zero encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: divide by zero encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# Num rows: 11
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 2
# Not enough data
# list lengths: 0, 6
# Not enough data
# list lengths: 0, 1
# Not enough data
# list lengths: 2, 2
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 2, 6
# Not enough data
# list lengths: 2, 1
# Not enough data
# list lengths: 6, 1
# Not enough data
# num scores: 115
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: divide by zero encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: divide by zero encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# Skipping Empty Data
# Skipping Empty Data
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\hrv\hrv_time.py:172: RuntimeWarning: invalid value encountered in scalar divide
#   out["CVNN"] = out["SDNN"] / out["MeanNN"]
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\hrv\hrv_time.py:173: RuntimeWarning: invalid value encountered in scalar divide
#   out["CVSD"] = out["RMSSD"] / out["MeanNN"]
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\hrv\hrv_time.py:178: RuntimeWarning: invalid value encountered in scalar divide
#   out["MCVNN"] = out["MadNN"] / out["MedianNN"]  # Normalized
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\hrv\hrv_time.py:180: RuntimeWarning: invalid value encountered in scalar divide
#   out["SDRMSSD"] = out["SDNN"] / out["RMSSD"]  # Sollers (2007)
# Error processing signal: zero-size array to reduction operation maximum which has no identity
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: divide by zero encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: divide by zero encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: divide by zero encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: divide by zero encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# Skipping Empty Data
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: divide by zero encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: divide by zero encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: divide by zero encountered in divide
#   mrrs /= th2
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# list lengths: 14, 41
# Significant difference between SBS_neg1 and SBS_one with Cohen's d: 0.5814
# Significant difference between SBS_neg1 and SBS_one with Hedges' g: 0.5732
# list lengths: 14, 23
# list lengths: 33, 41
# list lengths: 33, 23
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# Significant difference between SBS_neg1 and SBS_zero with Cohen's d: -0.7428
# Significant difference between SBS_neg1 and SBS_zero with Hedges' g: -0.7304
# list lengths: 14, 41
# Significant difference between SBS_neg1 and SBS_one with Cliff's Delta: -0.5784
# Significant difference between SBS_neg1 and SBS_one with Cohen's d: -1.2378
# Significant difference between SBS_neg1 and SBS_one with Hedges' g: -1.2202
# list lengths: 14, 23
# Significant difference between SBS_neg1 and SBS_two with Cliff's Delta: -0.6584
# Significant difference between SBS_neg1 and SBS_two with Cohen's d: -1.3217
# Significant difference between SBS_neg1 and SBS_two with Hedges' g: -1.2932
# list lengths: 33, 41
# Significant difference between SBS_zero and SBS_one with Cohen's d: -0.6318
# Significant difference between SBS_zero and SBS_one with Hedges' g: -0.6252
# list lengths: 33, 23
# Significant difference between SBS_zero and SBS_two with Cohen's d: -0.8183
# Significant difference between SBS_zero and SBS_two with Hedges' g: -0.8069
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# list lengths: 14, 41
# Significant difference between SBS_neg1 and SBS_one with Cohen's d: -0.9249
# Significant difference between SBS_neg1 and SBS_one with Hedges' g: -0.9117
# list lengths: 14, 23
# Significant difference between SBS_neg1 and SBS_two with Cohen's d: -0.9609
# Significant difference between SBS_neg1 and SBS_two with Hedges' g: -0.9402
# list lengths: 33, 41
# Significant difference between SBS_zero and SBS_one with Cohen's d: -0.5571
# Significant difference between SBS_zero and SBS_one with Hedges' g: -0.5512
# list lengths: 33, 23
# Significant difference between SBS_zero and SBS_two with Cohen's d: -0.6657
# Significant difference between SBS_zero and SBS_two with Hedges' g: -0.6564
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# Significant difference between SBS_neg1 and SBS_zero with Cohen's d: -0.8524
# Significant difference between SBS_neg1 and SBS_zero with Hedges' g: -0.8381
# list lengths: 14, 41
# Significant difference between SBS_neg1 and SBS_one with Cliff's Delta: -0.6098
# Significant difference between SBS_neg1 and SBS_one with Cohen's d: -1.1001
# Significant difference between SBS_neg1 and SBS_one with Hedges' g: -1.0845
# list lengths: 14, 23
# Significant difference between SBS_neg1 and SBS_two with Cliff's Delta: -0.7329
# Significant difference between SBS_neg1 and SBS_two with Cohen's d: -1.3909
# Significant difference between SBS_neg1 and SBS_two with Hedges' g: -1.3608
# list lengths: 33, 41
# Significant difference between SBS_zero and SBS_one with Cohen's d: -0.5499
# Significant difference between SBS_zero and SBS_one with Hedges' g: -0.5441
# list lengths: 33, 23
# Significant difference between SBS_zero and SBS_two with Cohen's d: -0.8551
# Significant difference between SBS_zero and SBS_two with Hedges' g: -0.8432
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# Error in DTW calculation: tuple index out of range
# list lengths: 14, 41
# Error in DTW calculation: tuple index out of range
# list lengths: 14, 23
# Error in DTW calculation: tuple index out of range
# list lengths: 33, 41
# Error in DTW calculation: tuple index out of range
# list lengths: 33, 23
# Error in DTW calculation: tuple index out of range
# list lengths: 41, 23
# Error in DTW calculation: tuple index out of range
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# Error in DTW calculation: tuple index out of range
# list lengths: 14, 41
# Error in DTW calculation: tuple index out of range
# Significant difference between SBS_neg1 and SBS_one with Cliff's Delta: -0.5889
# list lengths: 14, 23
# Error in DTW calculation: tuple index out of range
# Significant difference between SBS_neg1 and SBS_two with Cliff's Delta: -0.6584
# list lengths: 33, 41
# Error in DTW calculation: tuple index out of range
# list lengths: 33, 23
# Error in DTW calculation: tuple index out of range
# list lengths: 41, 23
# Error in DTW calculation: tuple index out of range
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# Error in DTW calculation: tuple index out of range
# list lengths: 14, 41
# Error in DTW calculation: tuple index out of range
# list lengths: 14, 23
# Error in DTW calculation: tuple index out of range
# list lengths: 33, 41
# Error in DTW calculation: tuple index out of range
# list lengths: 33, 23
# Error in DTW calculation: tuple index out of range
# list lengths: 41, 23
# Error in DTW calculation: tuple index out of range
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# Error in DTW calculation: tuple index out of range
# list lengths: 14, 41
# Error in DTW calculation: tuple index out of range
# Significant difference between SBS_neg1 and SBS_one with Cliff's Delta: -0.4948
# list lengths: 14, 23
# Error in DTW calculation: tuple index out of range
# list lengths: 33, 41
# Error in DTW calculation: tuple index out of range
# list lengths: 33, 23
# Error in DTW calculation: tuple index out of range
# list lengths: 41, 23
# Error in DTW calculation: tuple index out of range
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# list lengths: 14, 41
# Significant difference between SBS_neg1 and SBS_one with Cohen's d: -0.7074
# Significant difference between SBS_neg1 and SBS_one with Hedges' g: -0.6973
# list lengths: 14, 23
# Significant difference between SBS_neg1 and SBS_two with Cliff's Delta: -0.5217
# Significant difference between SBS_neg1 and SBS_two with Cohen's d: -0.8081
# Significant difference between SBS_neg1 and SBS_two with Hedges' g: -0.7907
# list lengths: 33, 41
# list lengths: 33, 23
# Significant difference between SBS_zero and SBS_two with Cohen's d: -0.6506
# Significant difference between SBS_zero and SBS_two with Hedges' g: -0.6415
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# list lengths: 14, 41
# Significant difference between SBS_neg1 and SBS_one with Cohen's d: -0.7073
# Significant difference between SBS_neg1 and SBS_one with Hedges' g: -0.6972
# list lengths: 14, 23
# Significant difference between SBS_neg1 and SBS_two with Cliff's Delta: -0.5217
# Significant difference between SBS_neg1 and SBS_two with Cohen's d: -0.8081
# Significant difference between SBS_neg1 and SBS_two with Hedges' g: -0.7907
# list lengths: 33, 41
# list lengths: 33, 23
# Significant difference between SBS_zero and SBS_two with Cohen's d: -0.6506
# Significant difference between SBS_zero and SBS_two with Hedges' g: -0.6415
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# Significant difference between SBS_neg1 and SBS_zero with Cohen's d: -0.8863
# Significant difference between SBS_neg1 and SBS_zero with Hedges' g: -0.8714
# list lengths: 14, 41
# Significant difference between SBS_neg1 and SBS_one with Cliff's Delta: -0.6446
# Significant difference between SBS_neg1 and SBS_one with Cohen's d: -1.3507
# Significant difference between SBS_neg1 and SBS_one with Hedges' g: -1.3315
# list lengths: 14, 23
# Significant difference between SBS_neg1 and SBS_two with Cliff's Delta: -0.7081
# Significant difference between SBS_neg1 and SBS_two with Cohen's d: -1.4389
# Significant difference between SBS_neg1 and SBS_two with Hedges' g: -1.4079
# list lengths: 33, 41
# Significant difference between SBS_zero and SBS_one with Cohen's d: -0.6253
# Significant difference between SBS_zero and SBS_one with Hedges' g: -0.6187
# list lengths: 33, 23
# Significant difference between SBS_zero and SBS_two with Cohen's d: -0.7965
# Significant difference between SBS_zero and SBS_two with Hedges' g: -0.7853
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# Significant difference between SBS_neg1 and SBS_zero with Cohen's d: -0.6214
# ...
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# Significant difference between SBS_neg1 and SBS_zero with Cliff's Delta: 0.5368
# Significant difference between SBS_neg1 and SBS_zero with Cohen's d: 0.9749
# Significant difference between SBS_neg1 and SBS_zero with Hedges' g: 0.9586
# list lengths: 14, 41
# Significant difference between SBS_neg1 and SBS_one with Cliff's Delta: 0.5784
# Significant difference between SBS_neg1 and SBS_one with Cohen's d: 1.0890
# Significant difference between SBS_neg1 and SBS_one with Hedges' g: 1.0735
# list lengths: 14, 23
# Significant difference between SBS_neg1 and SBS_two with Cohen's d: 0.8916
# Significant difference between SBS_neg1 and SBS_two with Hedges' g: 0.8724
# list lengths: 33, 41
# list lengths: 33, 23
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# Significant difference between SBS_neg1 and SBS_zero with Cohen's d: 0.6192
# Significant difference between SBS_neg1 and SBS_zero with Hedges' g: 0.6088
# list lengths: 14, 41
# list lengths: 14, 23
# list lengths: 33, 41
# list lengths: 33, 23
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# list lengths: 14, 41
# list lengths: 14, 23
# list lengths: 33, 41
# list lengths: 33, 23
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# list lengths: 14, 41
# Significant difference between SBS_neg1 and SBS_one with Cohen's d: -0.5774
# Significant difference between SBS_neg1 and SBS_one with Hedges' g: -0.5692
# list lengths: 14, 23
# Significant difference between SBS_neg1 and SBS_two with Cohen's d: -0.6684
# Significant difference between SBS_neg1 and SBS_two with Hedges' g: -0.6540
# list lengths: 33, 41
# list lengths: 33, 23
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# list lengths: 14, 41
# Significant difference between SBS_neg1 and SBS_one with Cliff's Delta: -0.5331
# Significant difference between SBS_neg1 and SBS_one with Cohen's d: -0.8595
# Significant difference between SBS_neg1 and SBS_one with Hedges' g: -0.8473
# list lengths: 14, 23
# Significant difference between SBS_neg1 and SBS_two with Cohen's d: -0.8138
# Significant difference between SBS_neg1 and SBS_two with Hedges' g: -0.7963
# list lengths: 33, 41
# Significant difference between SBS_zero and SBS_one with Cohen's d: -0.5067
# Significant difference between SBS_zero and SBS_one with Hedges' g: -0.5015
# list lengths: 33, 23
# Significant difference between SBS_zero and SBS_two with Cohen's d: -0.5874
# Significant difference between SBS_zero and SBS_two with Hedges' g: -0.5792
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# Significant difference between SBS_neg1 and SBS_zero with Cohen's d: 0.8331
# Significant difference between SBS_neg1 and SBS_zero with Hedges' g: 0.8191
# list lengths: 14, 41
# Significant difference between SBS_neg1 and SBS_one with Cliff's Delta: 0.5052
# Significant difference between SBS_neg1 and SBS_one with Cohen's d: 0.9921
# Significant difference between SBS_neg1 and SBS_one with Hedges' g: 0.9780
# list lengths: 14, 23
# Significant difference between SBS_neg1 and SBS_two with Cliff's Delta: 0.5155
# Significant difference between SBS_neg1 and SBS_two with Cohen's d: 1.0416
# Significant difference between SBS_neg1 and SBS_two with Hedges' g: 1.0191
# list lengths: 33, 41
# list lengths: 33, 23
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# Significant difference between SBS_neg1 and SBS_zero with Cohen's d: 0.6009
# Significant difference between SBS_neg1 and SBS_zero with Hedges' g: 0.5909
# list lengths: 14, 41
# Significant difference between SBS_neg1 and SBS_one with Cliff's Delta: 0.5366
# Significant difference between SBS_neg1 and SBS_one with Cohen's d: 0.9778
# Significant difference between SBS_neg1 and SBS_one with Hedges' g: 0.9639
# list lengths: 14, 23
# Significant difference between SBS_neg1 and SBS_two with Cliff's Delta: 0.5217
# Significant difference between SBS_neg1 and SBS_two with Cohen's d: 0.9861
# Significant difference between SBS_neg1 and SBS_two with Hedges' g: 0.9648
# list lengths: 33, 41
# list lengths: 33, 23
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# Significant difference between SBS_neg1 and SBS_zero with Cohen's d: -0.6776
# Significant difference between SBS_neg1 and SBS_zero with Hedges' g: -0.6662
# list lengths: 14, 41
# Significant difference between SBS_neg1 and SBS_one with Cliff's Delta: -0.6167
# Significant difference between SBS_neg1 and SBS_one with Cohen's d: -1.2522
# Significant difference between SBS_neg1 and SBS_one with Hedges' g: -1.2344
# list lengths: 14, 23
# Significant difference between SBS_neg1 and SBS_two with Cliff's Delta: -0.6957
# Significant difference between SBS_neg1 and SBS_two with Cohen's d: -1.4924
# Significant difference between SBS_neg1 and SBS_two with Hedges' g: -1.4602
# list lengths: 33, 41
# Significant difference between SBS_zero and SBS_one with Cohen's d: -0.6423
# Significant difference between SBS_zero and SBS_one with Hedges' g: -0.6355
# list lengths: 33, 23
# Significant difference between SBS_zero and SBS_two with Cliff's Delta: -0.4756
# Significant difference between SBS_zero and SBS_two with Cohen's d: -0.9329
# Significant difference between SBS_zero and SBS_two with Hedges' g: -0.9199
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# list lengths: 14, 41
# Significant difference between SBS_neg1 and SBS_one with Cliff's Delta: 0.5331
# Significant difference between SBS_neg1 and SBS_one with Cohen's d: 0.9757
# Significant difference between SBS_neg1 and SBS_one with Hedges' g: 0.9619
# list lengths: 14, 23
# Significant difference between SBS_neg1 and SBS_two with Cliff's Delta: 0.5155
# Significant difference between SBS_neg1 and SBS_two with Cohen's d: 0.6350
# Significant difference between SBS_neg1 and SBS_two with Hedges' g: 0.6213
# list lengths: 33, 41
# list lengths: 33, 23
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# list lengths: 14, 41
# list lengths: 14, 23
# Significant difference between SBS_neg1 and SBS_two with Cohen's d: 0.6144
# Significant difference between SBS_neg1 and SBS_two with Hedges' g: 0.6012
# list lengths: 33, 41
# list lengths: 33, 23
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# list lengths: 14, 41
# list lengths: 14, 23
# list lengths: 33, 41
# list lengths: 33, 23
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# list lengths: 14, 41
# list lengths: 14, 23
# Significant difference between SBS_neg1 and SBS_two with Cohen's d: 0.5121
# Significant difference between SBS_neg1 and SBS_two with Hedges' g: 0.5011
# list lengths: 33, 41
# list lengths: 33, 23
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# list lengths: 14, 41
# Significant difference between SBS_neg1 and SBS_one with Cohen's d: 0.8148
# Significant difference between SBS_neg1 and SBS_one with Hedges' g: 0.8032
# list lengths: 14, 23
# Significant difference between SBS_neg1 and SBS_two with Cohen's d: 0.7681
# Significant difference between SBS_neg1 and SBS_two with Hedges' g: 0.7515
# list lengths: 33, 41
# list lengths: 33, 23
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# Significant difference between SBS_neg1 and SBS_zero with Cohen's d: 0.7336
# Significant difference between SBS_neg1 and SBS_zero with Hedges' g: 0.7213
# list lengths: 14, 41
# Significant difference between SBS_neg1 and SBS_one with Cliff's Delta: 0.5610
# Significant difference between SBS_neg1 and SBS_one with Cohen's d: 1.0797
# Significant difference between SBS_neg1 and SBS_one with Hedges' g: 1.0643
# list lengths: 14, 23
# list lengths: 33, 41
# list lengths: 33, 23
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# list lengths: 14, 41
# list lengths: 14, 23
# list lengths: 33, 41
# list lengths: 33, 23
# list lengths: 41, 23
# Num rows: 111
# list lengths: 0, 14
# Not enough data
# list lengths: 0, 33
# Not enough data
# list lengths: 0, 41
# Not enough data
# list lengths: 0, 23
# Not enough data
# list lengths: 14, 33
# list lengths: 14, 41
# Significant difference between SBS_neg1 and SBS_one with Cohen's d: 0.5145
# Significant difference between SBS_neg1 and SBS_one with Hedges' g: 0.5072
# list lengths: 14, 23
# list lengths: 33, 41
# list lengths: 33, 23
# list lengths: 41, 23
# num scores: 130
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\hrv\hrv_nonlinear.py:529: NeuroKitWarning: DFA_alpha2 related indices will not be calculated. The maximum duration of the windows provided for the long-term correlation is smaller than the minimum duration of windows. Refer to the `scale` argument in `nk.fractal_dfa()` for more information.
#   warn(
# Skipping Empty Data
# c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\signal\signal_fixpeaks.py:307: RuntimeWarning: invalid value encountered in divide
#   mrrs /= th2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 32
#      29 try:
#      30     # Compute peaks and HRV indices
#      31     peaks, info = nk.ecg_peaks(current_signal, sampling_rate=250, correct_artifacts=True)
# ---> 32     hrv_indices = nk.hrv(peaks, sampling_rate=250, show=False)
#      33     hrv_indices.dropna(axis=1)
#      34     hrv_indices_final = pd.concat([hrv_indices_final, hrv_indices], axis=0, ignore_index=True, sort=False)
#
# File c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\hrv\hrv.py:107, in hrv(peaks, sampling_rate, show, **kwargs)
#     105 out.append(hrv_time(peaks, sampling_rate=sampling_rate))
#     106 out.append(hrv_frequency(peaks, sampling_rate=sampling_rate))
# --> 107 out.append(hrv_nonlinear(peaks, sampling_rate=sampling_rate))
#     109 # Compute RSA if rsp data is available
#     110 if isinstance(peaks, pd.DataFrame):
#
# File c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\hrv\hrv_nonlinear.py:297, in hrv_nonlinear(peaks, sampling_rate, show, **kwargs)
#     295 out["MSEn"], _ = entropy_multiscale(rri, dimension=2, tolerance=tolerance, method="MSEn")
#     296 out["CMSEn"], _ = entropy_multiscale(rri, dimension=2, tolerance=tolerance, method="CMSEn")
# --> 297 out["RCMSEn"], _ = entropy_multiscale(rri, dimension=2, tolerance=tolerance, method="RCMSEn")
#     299 out["CD"], _ = fractal_correlation(rri, delay=1, dimension=2, **kwargs)
#     300 out["HFD"], _ = fractal_higuchi(rri, k_max=10, **kwargs)
#
# File c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\complexity\entropy_multiscale.py:330, in entropy_multiscale(signal, scale, dimension, tolerance, method, show, **kwargs)
#     313 info = {
#     314     "Method": method,
#     315     "Algorithm": algorithm.__name__,
#    (...)
#     324     )[0],
#     325 }
#     327 # Compute entropy for each coarsegrained segment
#     328 info["Value"] = np.array(
#     329     [
# --> 330         _entropy_multiscale(
#     331             signal,
#     332             scale=scale,
#     333             coarsegraining=coarsegraining,
#     334             algorithm=algorithm,
#     335             dimension=dimension,
#     336             tolerance=info["Tolerance"],
#     337             refined=refined,
#     338             **kwargs,
#     339         )
#     340         for scale in info["Scale"]
#     341     ]
#     342 )
#     344 # Remove inf, nan and 0
#     345 mse = info["Value"][np.isfinite(info["Value"])]
#
# File c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\complexity\entropy_multiscale.py:430, in _entropy_multiscale(signal, scale, coarsegraining, algorithm, dimension, tolerance, refined, **kwargs)
#     414     return _validmean(
#     415         [
#     416             algorithm(
#    (...)
#     424         ]
#     425     )
#     426 # RCMSE
#     427 else:
#     428     phis = np.array(
#     429         [
# --> 430             _phi(
#     431                 coarse[i],
#     432                 delay=1,
#     433                 dimension=dimension,
#     434                 tolerance=tolerance,
#     435                 approximate=False,
#     436             )[0]
#     437             for i in range(len(coarse))
#     438         ]
#     439     )
#     440     # Average all phi of the same dimension, then divide, then log
#     441     return _phi_divide([_validmean(phis[:, 0]), _validmean(phis[:, 1])])
#
# File c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\complexity\utils_entropy.py:57, in _phi(signal, delay, dimension, tolerance, distance, approximate, fuzzy, kdtree1, kdtree2, **kwargs)
#      45 # Embed signal at m and m+1
#      46 embedded1, count1, kdtree1 = _get_count(
#      47     signal,
#      48     delay,
#    (...)
#      54     kdtree=kdtree1,
#      55 )
# ---> 57 embedded2, count2, kdtree2 = _get_count(
#      58     signal,
#      59     delay,
#      60     dimension + 1,
#      61     tolerance,
#      62     distance=distance,
#      63     approximate=True,
#      64     fuzzy=fuzzy,
#      65     kdtree=kdtree2,
#      66 )
#      68 # Initialize phi
#      69 phi = np.zeros(2)
#
# File c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\complexity\utils_entropy.py:123, in _get_count(signal, delay, dimension, tolerance, distance, approximate, fuzzy, kdtree, n, **kwargs)
#     115 """
#     116 This is usually the bottleneck for several complexity methods, in particular in the counting.
#     117 That's why we allow the possibility of giving kdtrees as pre-computed (used in the optimization
#     118 of tolerance via MaxApEn which computes iteratively the value with multiple tolerances).
#     119 However, more improvements are welcome!
#     120 """
#     121 # Get embedded
#     122 # -------------------
# --> 123 embedded = complexity_embedding(signal, delay=delay, dimension=dimension)
#     124 if approximate is False:
#     125     embedded = embedded[:-1]  # Removes the last line
#
# File c:\Users\HP\anaconda3\envs\PHANGS\Lib\site-packages\neurokit2\complexity\utils_complexity_embedding.py:150, in complexity_embedding(signal, delay, dimension, show, **kwargs)
#     148 Y = np.zeros((dimension, N - (dimension - 1) * delay))
#     149 for i in range(dimension):
# --> 150     Y[i] = signal[i * delay : i * delay + Y.shape[1]]
#     151 embedded = Y.T
#     153 if show is True:
#
# KeyboardInterrupt:
